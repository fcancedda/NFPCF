# %%
import pandas as pd
import seaborn as sns
import numpy as np
from data_loader import LoadData

data = LoadData()
# Out:
#    uid_old  mid_old  rating                date  gender  age  job_old  uid  \
# 0        2     1357       5 2000-12-31 21:38:29       1   56       16    0
# 1        2     3068       4 2000-12-31 21:43:20       1   56       16    0
# 2        2     1537       4 2000-12-31 21:53:40       1   56       16    0
# 3        2      647       3 2000-12-31 21:49:11       1   56       16    0
# 4        2     2194       4 2000-12-31 21:48:17       1   56       16    0
#
#    mid  job
# 0    0    0
# 1    1    0
# 2    2    0
# 3    3    0
# 4    4    0
# ratings 7.605123043060303
# features 0.02297496795654297
# merge 0.0906839370727539
# negatives 8.537978172302246
# total 16.256760120391846

# %%
data.fd.describe()
# Out:
#              uid_old        mid_old         rating         gender  \
# count  817317.000000  817317.000000  817317.000000  817317.000000
# mean     3054.289346    1865.437321       3.590070       0.755122
# std      1726.920367    1095.196379       1.110834       0.430015
# min         2.000000       1.000000       1.000000       0.000000
# 25%      1546.000000    1032.000000       3.000000       1.000000
# 50%      3145.000000    1834.000000       4.000000       1.000000
# 75%      4489.000000    2770.000000       4.000000       1.000000
# max      6040.000000    3952.000000       5.000000       1.000000
#
#                  age        job_old            uid            mid  \
# count  817317.000000  817317.000000  817317.000000  817317.000000
# mean       30.265557       8.979436    2460.254150     866.731426
# std        10.762840       6.185765    1409.022636     728.813488
# min         1.000000       1.000000       0.000000       0.000000
# ...

# %%
data.tr
# Out:
#          uid   mid  rating
# 0          0     0       1
# 1          0     1       1
# 2          0     2       1
# 3          0     3       1
# 4          0     4       1
# ...      ...   ...     ...
# 836992  4919  2921       1
# 836993  4919  2926       1
# 836994  4919  3026       1
# 836995  4919  3311       1
# 836996  4919  3349       1
#
# [836997 rows x 3 columns]

# %%
data._load_ratings()
# Out:
#           uid   mid  rating                date
# 0           1  1193       5 2000-12-31 22:12:40
# 1           1   661       3 2000-12-31 22:35:09
# 2           1   914       3 2000-12-31 22:32:48
# 3           1  3408       4 2000-12-31 22:04:35
# 4           1  2355       5 2001-01-06 23:38:11
# ...       ...   ...     ...                 ...
# 1000204  6040  1091       1 2000-04-26 02:35:41
# 1000205  6040  1094       5 2000-04-25 23:21:27
# 1000206  6040   562       5 2000-04-25 23:19:06
# 1000207  6040  1096       4 2000-04-26 02:20:48
# 1000208  6040  1097       4 2000-04-26 02:19:29
#
# [999611 rows x 4 columns]

# %%
data.fd[data.fd.uid == 0]
# Out:
#      uid_old  mid_old  rating                date  gender  age  job_old  uid  \
# 0          2     1357       5 2000-12-31 21:38:29       1   56       16    0
# 1          2     3068       4 2000-12-31 21:43:20       1   56       16    0
# 2          2     1537       4 2000-12-31 21:53:40       1   56       16    0
# 3          2      647       3 2000-12-31 21:49:11       1   56       16    0
# 4          2     2194       4 2000-12-31 21:48:17       1   56       16    0
# ..       ...      ...     ...                 ...     ...  ...      ...  ...
# 124        2      356       5 2000-12-31 21:54:46       1   56       16    0
# 125        2     1245       2 2000-12-31 21:46:40       1   56       16    0
# 126        2     1246       5 2000-12-31 21:50:18       1   56       16    0
# 127        2     3893       1 2000-12-31 21:52:15       1   56       16    0
# 128        2     1247       5 2000-12-31 21:37:32       1   56       16    0
#
#      mid  job  latest
# ...

# %%
data.tr[data.tr.uid == 0]
# Out:
#      uid   mid  rating
# 0      0     0       1
# 1      0     1       1
# 2      0     2       1
# 3      0     3       1
# 4      0     4       1
# ..   ...   ...     ...
# 128    0   344       0
# 129    0   884       0
# 130    0  1474       0
# 131    0  1487       0
# 132    0  2125       0
#
# [133 rows x 3 columns]

# %%
data.fd.gender.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/kf/j1jq_1qs78n4gd1vczc8vfw80000gn/T/ipykernel_68768/2611701024.py in <module>
# ----> 1 data.fd.gender.plot(kind='bar')
#       2
#
# ~/Documents/Scool/NFPCF/venv/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/Documents/Scool/NFPCF/venv/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
sns.barplot(data.fd.gender.value_counts())

# %%
import matplotlib.pyplot as plt

ax = sns.countplot(x='gender', data=data.fd, palette="coolwarm")
ax.set(title='common xlabel')
ax.set_xticks([0, 1]) # <--- set the ticks first
ax.set_xticklabels()
# plt.style.use("dark_background")

# %%
colors = sns.color_palette('pastel')[:2]
len(colors)

# %%
#create pie chart
data.fd.gender.plot.pie()  #, labels = , colors = colors, autopct='%.0f%%')
